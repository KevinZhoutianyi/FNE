# %%
from utils import *
# Specify directories and methods
model_size_dirs = [
    "/home/{yourname}/FNE/result/learningcurve_modelsize/train_from_scratch/meta-llama/Llama-3.2-1B-Instruct/int_multiplication2",
    "/home/{yourname}/FNE/result/learningcurve_modelsize/pretrained/meta-llama/Llama-3.2-1B-Instruct/int_multiplication2"
]

main(
    base_dirs=model_size_dirs,
    methods=["fne", "regular", "xval"],
    x_key="model_size",
    y_keys={"accuracy": "Accuracy (%)", "r2": "R²"},
    is_model_size=True,
    y_lim={"r2":[0.9999, 1.00001] } , # Set y-limits for R² plot
    legend_location='best',                # For R²
    legend_location_accuracy='lower right', # For Accuracy
    simple_version=True
)

data_size_dirs = [
    "/home/{yourname}/FNE/result/learningcurve_datasize/train_from_scratch/meta-llama/Llama-3.2-1B-Instruct/int_multiplication2",
    "/home/{yourname}/FNE/result/learningcurve_datasize/pretrained/meta-llama/Llama-3.2-1B-Instruct/int_multiplication2"
]

main(
    base_dirs=data_size_dirs,
    methods=["fne", "regular", "xval"],
    x_key="datasize",
    y_keys={"accuracy": "Accuracy (%)", "r2": "R²"},
    is_model_size=False,
    y_lim={"r2": [0.99, 1.001]},  # Set y-limits for R² plot
    simple_version=True
)
